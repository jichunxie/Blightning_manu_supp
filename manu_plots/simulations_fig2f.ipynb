# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data
X, Y = np.meshgrid(np.linspace(0, 1, 100),
                   np.linspace(0, 1.1, 100))
Z = (2 * X * Y/(X+Y))
n = [5,6,7,8,9,10,11,12]
# Contour
fig, ax = plt.subplots()
cnt = ax.contour(X, Y, Z,levels=11,cmap = "Reds",fontsize=14)

ax.clabel(cnt, cnt.levels, inline = True, fontsize = 10)
points_x = [0.1666667, 0.2666667,0.2000000, 0.1000000, 0.5666667,0.5666667,0.5666667,0.5666667]
points_y = [0.2941176,0.2666667,0.5,1, 1,1, 1,1]

plt.scatter(points_x, points_y,  marker='o', label='Points',color = 'red')
plt.xlabel("Sensitivity",fontsize=18)
plt.ylabel("1 - FDR",fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#position_x = [0.1666667, 0.2666667,0.2000000, 0.1000000, 0.54,0.58,0.63,0.68]
#position_y = [0.2941176,0.2666667,0.5,1, 1,1, 1,1]

#for i, txt in enumerate(n):
#    ax.annotate(txt, (position_x[i], position_y[i]),fontsize=14)
plt.gcf().set_size_inches(6, 9)
plt.savefig('stabilitycheck.jpeg', format="jpeg", dpi=1200)
plt.show()
# Out:
# /var/folders/xp/8xkmmg3j5_n62pmcjwhfkwzh0000gq/T/ipykernel_72646/49879362.py:4: RuntimeWarning: invalid value encountered in divide
#   Z = (2 * X * Y/(X+Y))
# /var/folders/xp/8xkmmg3j5_n62pmcjwhfkwzh0000gq/T/ipykernel_72646/49879362.py:8: UserWarning: The following kwargs were not used by contour: 'fontsize'
#   cnt = ax.contour(X, Y, Z,levels=11,cmap = "Reds",fontsize=14)
